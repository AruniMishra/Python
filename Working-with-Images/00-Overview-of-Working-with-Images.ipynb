# %%
from PIL import Image

# %%
my_image = Image.open('aruni.jpg')

# %%
type(my_image)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
my_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=460x460 at 0x11A90674E50>

# %%
my_image.size
# Out:
# (460, 460)

# %%
my_image.filename
# Out:
# 'aruni.jpg'

# %%
h,w = my_image.size

# %%
new_h = int(h/3)
new_w = int(w/3)

# %%
my_image.resize((new_h,new_w))
# Out:
# <PIL.Image.Image image mode=RGB size=153x153 at 0x11A93C90700>

# %%
my_image.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGB size=460x460 at 0x11A91B63820>

# %%
my_image.putalpha(128)

# %%
my_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGBA size=460x460 at 0x11A90674E50>
